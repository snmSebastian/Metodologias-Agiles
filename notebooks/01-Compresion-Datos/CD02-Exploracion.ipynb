# %% [markdown]
# ##### Importación de librerías

# %%
import pandas as pd
#from ydata_profiling import ProfileReport
import dtale as dt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/sebastian/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# ----
#
# ##### Lectura de los datasets

# %%
df_creditos = pd.read_csv("../../data/raw/datos_creditos.csv", sep=";")
df_creditos.head(1)
# Out:
#     id_cliente  edad  ...  estado_credito  falta_pago
# 0  713061558.0    22  ...               1           Y
#
# [1 rows x 12 columns]

# %%
df_tarjetas = pd.read_csv("../../data/raw/datos_tarjetas.csv", sep=";")
df_tarjetas.head(1)
# Out:
#     id_cliente  antiguedad_cliente  ... operaciones_ult_12m personas_a_cargo
# 0  713061558.0                36.0  ...                24.0              2.0
#
# [1 rows x 11 columns]

# %% [markdown]
# ----
#
# ##### Descripción de los datasets

# %%
def reporte_descripcion_dataset(df):
    columnas = df.columns
    print("Columnas del dataset:\n")
    for col in columnas:
        print(col)
    print(f"\nCantidad de filas: {df.shape[0]}")

# %%
print("Descripción del dataset 'datos_creditos'")
reporte_descripcion_dataset(df_creditos)
# Out:
# Descripción del dataset 'datos_creditos'
# Columnas del dataset:
#
# id_cliente
# edad
# importe_solicitado
# duracion_credito
# antiguedad_empleado
# situacion_vivienda
# ingresos
# objetivo_credito
# pct_ingreso
# tasa_interes
# estado_credito
# falta_pago
#
# Cantidad de filas: 10127

# %%
print("Descripción del dataset 'datos_tarjetas'")
reporte_descripcion_dataset(df_tarjetas)
# Out:
# Descripción del dataset 'datos_tarjetas'
# Columnas del dataset:
#
# id_cliente
# antiguedad_cliente
# estado_civil
# estado_cliente
# gastos_ult_12m
# genero
# limite_credito_tc
# nivel_educativo
# nivel_tarjeta
# operaciones_ult_12m
# personas_a_cargo
#
# Cantidad de filas: 10127

# %% [markdown]
# ----
#
# ##### Obtención de metadatos

# %%
# Se usa la librería dtale para poder obtener una vista interactiva de los datos

# Dataset: datos_creditos

creditos = dt.show(df_creditos)
creditos.open_browser()
# Out:
# 2023-12-05 21:46:57,052 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 186, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 162, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2023-12-05 21:47:24,056 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 458, in build
#     hist = self.build_hist(s, code)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 512, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 6204, in __getattr__
#     return object.__getattribute__(self, name)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 190, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 244, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!
# 2023-12-05 21:47:59,374 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 186, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 162, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2023-12-05 21:50:31,028 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 186, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 162, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2023-12-05 21:51:08,668 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 458, in build
#     hist = self.build_hist(s, code)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 512, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 6204, in __getattr__
#     return object.__getattribute__(self, name)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 190, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 244, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!
# 2023-12-05 21:51:23,007 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 186, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 162, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2023-12-05 21:51:27,350 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 458, in build
#     hist = self.build_hist(s, code)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 512, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 6204, in __getattr__
#     return object.__getattribute__(self, name)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 190, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 244, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!
# 2023-12-05 21:51:43,235 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 186, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 162, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/numpy/lib/histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Exception ignored in: <function Image.__del__ at 0x7f266325ae60>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 4056, in __del__
#     self.tk.call('image', 'delete', self.name)
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Variable.__del__ at 0x7f26633c36d0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 388, in __del__
#     if self._tk.getboolean(self._tk.call("info", "exists", self._name)):
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Variable.__del__ at 0x7f26633c36d0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 388, in __del__
#     if self._tk.getboolean(self._tk.call("info", "exists", self._name)):
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Variable.__del__ at 0x7f26633c36d0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 388, in __del__
#     if self._tk.getboolean(self._tk.call("info", "exists", self._name)):
# RuntimeError: main thread is not in main loop
# 2023-12-05 21:52:18,865 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/views.py", line 3110, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 458, in build
#     hist = self.build_hist(s, code)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/dtale/column_analysis.py", line 512, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 6204, in __getattr__
#     return object.__getattribute__(self, name)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 190, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "/home/sebastian/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py", line 244, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!

# %%
# Dataset: datos_tarjetas

tarjetas = dt.show(df_tarjetas)
tarjetas.open_browser()

# %% [markdown]
# ----
#
# ##### Gráficos de interés

# %%
plt.figure(figsize=(7,5))
sns.countplot(y=df_creditos['objetivo_credito'], order=df_creditos['objetivo_credito'].value_counts().index)
plt.show()
